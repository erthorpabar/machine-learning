# %%
''' pca 降维
————————数学原理————————
0 核心思想
找到权重最大的新坐标 并且筛选

1 归一化
减去平均值 = 数据移动到坐标原点
除以标准差 = 数据缩放到单位圆
x = (x-mean(x))/std(x)


2 数据
d(m,n) m 样本数量 n 特征


3 计算协方差矩阵
c = 1/(m-1) * d.T * d = (n,n)
左对角线 = 协方差 = 特征相关程度  相关总和为正 不相关总和为0
右对角线 = 方差 = 离散程度


4 求特征值 对角矩阵 λ(n,n)


5 求特征向量 矩阵 p(n,n)
P λ P.T = c
P.T c P = λ

6 排列特征重要性 取前b个特征向量 矩阵 p(n,b)
d' = p * d
(m,b) = (m,n) * (n,b)

————————案例————————

2 数据
d(m,n) m 样本数量 n 特征
d = [[-1,-2],
    [-1,0],
    [0,0],
    [2,1],
    [0,1]]


3 计算协方差矩阵(方便计算m取5)
c = 1/m * d.T * d =
1/m *
[[sum(x^2),sum(x*y)],
[sum(x*y),sum(y^2)]]
= 
[[6/5,4/5],
[4/5,6/5]],

4 求特征值 矩阵 λ
λ = [[2, 0],
    [0, 2/5]]

5 求c的特征向量 矩阵 p
p = [[1,1],
    [1,-1]]

6 n = 1
p(n-1) = [[1/√2,1/√2]
d' = p1 * d
= [-3/√2,-1/√2,0,3/√2,1/√2]

降低到n=1维度
新坐标为 p(n-1)
坐标值为 d'
'''
