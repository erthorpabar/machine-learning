# %%
''' 
历史统计数据
| 天气  | 温度  | 湿度  | 风速  | 户外运动 |
| ----- | ----- | ----- | ----- | -------- |
| 晴朗  | 热    | 高    | 低    | 是       |
| 阴天  | 温暖  | 高    | 高    | 是       |
| 下雨  | 冷    | 高    | 高    | 否       |
| 晴朗  | 温暖  | 低    | 低    | 是       |
| 晴朗  | 热    | 中    | 低    | 否       | 
| 阴天  | 热    | 中    | 高    | 是       |
| 下雨  | 温暖  | 高    | 低    | 否       |


核心公式
p(结果|条件) *p(条件) = p(条件|结果) * p(结果)
p(结果|条件) = p(条件|结果) * p(结果) / p(条件)


0 目标
p(户外运动 = 是 | 天气 = 晴朗, 温度 = 热, 湿度 = 高, 风速 = 低)

1 统计先验概率
p(户外运动 = 是) = 4/7
p(户外运动 = 否) = 3/7


2 统计条件概率
P(天气=晴朗|是) = 2/4 = 0.5 
P(温度=热|是) = 2/4 = 0.5 
P(湿度=高|是) = 2/4 = 0.5 
P(风速=低|是) = 2/4 = 0.5 


P(天气=晴朗|否) = 1/3 ≈ 0.333 
P(温度=热|否) = 1/3 ≈ 0.333 
P(湿度=高|否) = 2/3 ≈ 0.667 
P(风速=低|否) = 2/3 ≈ 0.667 


3 计算后验概率
p(是|晴朗，热，高，低) = p(晴朗|是) * p(热|是) * p(高|是) * p(低|是) * p(是) = 0.5 x 0.5 x 0.5 x 0.5 x (4/7) = 0.0357
p(否|晴朗，热，高，低) = p(晴朗|否) * p(热|否) * p(高|否) * p(低|否) * p(否) = 0.333 x 0.333 x 0.667 x 0.667 x (3/7) = 0.0212


4 比较后验概率
p(是|晴朗，热，高，低) > p(否|晴朗，热，高，低)
所以 预测 户外运动 = 是





'''
